# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kateryna Viniarska**
#
# Data Analyst

# %% [markdown]
# *I am interesting in data science, because I like to get the insights from the data and apply them to answer the business questions. I want also develop myself to Data Scientist Position.*

# %% [markdown]
# ### The following code tes, whether the water boils or not

# %%
def boils_or_not(temperature):
    if temperature == 100:
     return ("water boils")
    else: 
     return("water doesn't boil")

x=boils_or_not(40)
print(x)
# Out:
# water doesn't boil

# %% [markdown]
# Bullet list:
# * bananas
# * pineapples
# * apples
# * strawberries
#
#
# Table:
#
# | Fruit 1 | Fruit 2 | Fruit 3|
# |-------|-------|------|
# |bananas|apples|pineapples|
# |1|2|5|
#
# Hyperlink:
#
# [Link to cat image](https://www.google.com/search?q=cat&client=firefox-b-d&sxsrf=AJOqlzXEwq7Q1A-HYo1_4_AnRyrV3kDQQA:1677012020942&tbm=isch&source=iu&ictx=1&vet=1&fir=VRmao7FmvjTB6M%252CHkevFQZ5DYu7oM%252C_%253BeAP244UcF5wdYM%252CK6Qd9XWnQFQCoM%252C_%253BhMjxy8pUhhc4QM%252C3aBlXpmFZqFG2M%252C_%253BKl3KKhCsQyey_M%252CHkevFQZ5DYu7oM%252C_%253BGme9yscQxt6nYM%252CK6Qd9XWnQFQCoM%252C_%253BzP4N2WyGyDNkkM%252CMZs71HIAHkZnCM%252C_&usg=AI4_-kRoEqKQX4iBCUxL1m2LFg5X9zXAHQ&sa=X&ved=2ahUKEwjA7qrOvKf9AhWIX_EDHcjqB70Q_h16BAglEAE#imgrc=Gme9yscQxt6nYM)
#
# Code:
#
# ```python
# s = "Hi Python"
# print s
# ```
